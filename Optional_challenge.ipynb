# %%
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# Look at https://www.cs.toronto.edu/~kriz/cifar.html

# %% [markdown]
# Now let us see example for each class. Can you remember the classes available from the website above?

# %%
import numpy as np
import matplotlib.pyplot as plt

num_classes = len(np.unique(y_train))
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    ax.set_title(class_names[i])
    idx = np.where(y_train[:]==i)[0]
    features_idx = X_train[idx,::]
    rnd_img = np.random.randint(features_idx.shape[0])
    im = np.transpose(features_idx[rnd_img,::], (0, 1, 2))
    plt.imshow(im)
plt.show()

# %% [markdown]
# Now we will do some data preprocessing
#
#
# 1.   Change the features type i.e. X_train and X_test into float type
# 2.   Normalize the features as a scale of 0-255
# 3.   Convert the target vector i.e. Y_train and Y_test into one-hot vector

# %%
# step 1

#step 2

# step 3

# %% [markdown]
# **Now the CNN model!**
# Try to add layers with filters, padding, and activation. Try also maxpooling and batchnormalization between the layers. It is recommended to flatten some of the layers.

# %%
# here are some libraries that you may use
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
import keras.backend as K

model = Sequential()
#start adding layers using model.add

# %% [markdown]
# Now lets compile our model

# %%
# you need to choose optimizer, loss function, and scoring matrix in the compile arguments
model.compile(#fill this one)

# %% [markdown]
# Now your model is ready and you can summarize and visualize it, can you?

# %%
# print the model summary and visualzie the model

# %% [markdown]
# Now you have your model so what else? You need to train it! That's why we have X_train and others

# %% [markdown]
# **Model Training**

# %% [markdown]
# Feel free to use different batch sizes and epochs to find which is better for your model. Btw more epochs means more time needed for your model so keep that in mind!

# %%
# fit your model and use the test data as validation

# %% [markdown]
# Now it's time to evaluate the model using evaluate function

# %%
# evaluate your model you just fit your data to
